# %%
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM, Bidirectional, Conv2D, MaxPooling2D, Flatten, TimeDistributed, BatchNormalization, Reshape
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
import random
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# 2024-06-11 08:44:46.099775: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-11 08:44:46.099893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-11 08:44:46.228762: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
df = pd.read_csv('/kaggle/input/audio-dataset/Audios_Final')
df
# Out:
#          Emotion                                               file
# 0      surprised  /kaggle/input/speech-emotion-recognition-en/Ra...
# 1        neutral  /kaggle/input/speech-emotion-recognition-en/Ra...
# 2        disgust  /kaggle/input/speech-emotion-recognition-en/Ra...
# 3        disgust  /kaggle/input/speech-emotion-recognition-en/Ra...
# 4        neutral  /kaggle/input/speech-emotion-recognition-en/Ra...
# ...          ...                                                ...
# 12157  surprised  /kaggle/input/speech-emotion-recognition-en/Te...
# 12158  surprised  /kaggle/input/speech-emotion-recognition-en/Te...
# 12159  surprised  /kaggle/input/speech-emotion-recognition-en/Te...
# 12160  surprised  /kaggle/input/speech-emotion-recognition-en/Te...
# 12161  surprised  /kaggle/input/speech-emotion-recognition-en/Te...
#
# [12162 rows x 2 columns]

# %%
def stretch(data, rate=1):
    return librosa.effects.time_stretch(data, rate=rate)


def extract_mfcc_and_deltas_with_augmentation(file_path, max_pad_len=130, stretch_factor=1.2):
    audio, sample_rate = librosa.load(file_path, sr=None, duration=2.5, offset=0.6)
    stretched_audio = stretch(audio, rate=stretch_factor)

    # Function to extract MFCCs and their deltas from an audio sample
    def extract_and_pad_features(audio):
        # Extract MFCCs and their deltas
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfcc_delta = librosa.feature.delta(mfccs)
        mfcc_delta2 = librosa.feature.delta(mfccs, order=2)
        features = np.concatenate((mfccs, mfcc_delta, mfcc_delta2), axis=0)
        
        # Pad or truncate the features to ensure uniform size
        pad_width = max_pad_len - features.shape[1]
        if pad_width < 0:  # Truncate
            features = features[:, :max_pad_len]
        else:  # Pad with zeros
            features = np.pad(features, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
        return features

    normal_features = extract_and_pad_features(audio)
    stretched_features = extract_and_pad_features(stretched_audio)

    return normal_features, stretched_features

# %%
from tqdm import tqdm

feature_list = []
y = []

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    path = row['file']
    emotion = row['Emotion']
    
    normal_features, stretched_features = extract_mfcc_and_deltas_with_augmentation(path)
    
    # Append both sets of features to your feature list
    feature_list.append(normal_features)
    feature_list.append(stretched_features)
    
    # Append the emotion label twice, once for each set of features
    y.extend([emotion] * 2)
# Out:
# 100%|██████████| 12162/12162 [14:16<00:00, 14.20it/s]

# %%
# Assuming `feature_list` is a list of arrays, you might need to adjust shapes or concatenate along the correct axis
X = np.array(feature_list)
y = np.array(y)

# %%
np.save('new_features.npy', X)
np.save('new_labels.npy', y)

# %% [markdown]
# # Concatenating MFCCs

# %%
import numpy as np

# MFCC Features
X = np.load('/kaggle/input/final-audio-data/new_features.npy')
y = np.load('/kaggle/input/final-audio-data/new_labels.npy')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# Encode class values as integers
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)

# Convert integers to dummy (one-hot encoded) variables
dummy_y = to_categorical(encoded_y)

# %%
import numpy as np

# MFCC Features
# data = np.load('/kaggle/input/mfcc-all-audios/features.npy')
# labels = np.load('/kaggle/input/mfcc-all-audios/labels.npy')
data = X
labels = y

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.2, random_state=42)

# %%
# Extracting only Original
X_test = X_test[::2]  
y_test = y_test[::2]

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Initialize the StandardScaler
scaler = StandardScaler()

# Reshape the data to 2D for scaling (combining the first and third dimensions)
num_samples, num_features, num_steps = X_train.shape
X_train_reshaped = X_train.reshape(-1, num_features*num_steps)
X_test_reshaped = X_test.reshape(-1, num_features*num_steps)

# Fit on the training data and transform both training and test data.
scaler.fit(X_train_reshaped)
X_train_scaled = scaler.transform(X_train_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped)

# Reshape the scaled data back to its original 3D shape
X_train_scaled = X_train_scaled.reshape(num_samples, num_features, num_steps)
X_test_scaled = X_test_scaled.reshape(X_test.shape[0], num_features, num_steps)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, LSTM, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Layer
import tensorflow.keras.backend as K
import tensorflow as tf

input_shape = (120, 130)

model = Sequential([
    Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=input_shape, padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),
    
    Conv1D(filters=256, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),
    
    Conv1D(filters=256, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),
    
#     Conv1D(filters=256, kernel_size=3, activation='relu', padding='same'),
#     BatchNormalization(),
#     MaxPooling1D(pool_size=2),
#     Dropout(0.2),
    
    Bidirectional(LSTM(2048, return_sequences=True)),
    Bidirectional(LSTM(1024, return_sequences=True)),
    Bidirectional(LSTM(512)),
    
    # Dense layers
    Dense(128, activation='relu'),
    Dense(8, activation='softmax')  # Assuming 8 classes for emotion classification
])

# Compilation of the model
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 120, 256)       │       100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 120, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 60, 256)        │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 60, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 256)        │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 15, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 15, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 15, 4096)       │    37,765,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 15, 2048)       │    41,951,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 1024)           │    10,489,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 90,835,336 (346.51 MB)
#  Trainable params: 90,833,800 (346.50 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
history = model.fit(X_train_scaled, y_train, validation_data=(X_test_scaled, y_test), epochs=95, batch_size=64, callbacks=callbacks)
# Out:
# Epoch 1/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 86s 240ms/step - accuracy: 0.2020 - loss: 1.9153 - val_accuracy: 0.3872 - val_loss: 1.5093 - learning_rate: 0.0010
# Epoch 2/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 76s 250ms/step - accuracy: 0.4009 - loss: 1.4692 - val_accuracy: 0.4147 - val_loss: 1.4774 - learning_rate: 0.0010
# Epoch 3/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 76s 249ms/step - accuracy: 0.4730 - loss: 1.3250 - val_accuracy: 0.5171 - val_loss: 1.1940 - learning_rate: 0.0010
# Epoch 4/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━
95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 247ms/step - accuracy: 0.9563 - loss: 0.1225 - val_accuracy: 0.7924 - val_loss: 0.8395 - learning_rate: 0.0010
# Epoch 45/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 247ms/step - accuracy: 0.9643 - loss: 0.1007 - val_accuracy: 0.7998 - val_loss: 0.8178 - learning_rate: 0.0010
# Epoch 46/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9650 - loss: 0.1090 - val_accuracy: 0.7785 - val_loss: 0.9151 - learning_rate: 0.0010
# Epoch 47/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 247ms/step - accuracy: 0.9668 - loss: 0.1050 - val_accuracy: 0.8002 - val_loss: 0.7955 - learning_rate: 0.0010
# Epoch 48/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9679 - loss: 0.0921 - val_accuracy: 0.7748 - val_loss: 0.9677 - learning_rate: 0.0010
# Epoch 49/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9475 - loss: 0.1525 - val_accuracy: 0.8072 - val_loss: 0.7682 - learning_rate: 0.0010
# Epoch 50/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 82s 246ms/step - accuracy: 0.9693 - loss: 0.0904 - val_accuracy: 0.7941 - val_loss: 0.8696 - learning_rate: 0.0010
# Epoch 51/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9658 - loss: 0.1007 - val_accuracy: 0.7920 - val_loss: 0.8679 - learning_rate: 0.0010
# Epoch 52/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 74s 244ms/step - accuracy: 0.9696 - loss: 0.0887 - val_accuracy: 0.7924 - val_loss: 0.8433 - learning_rate: 0.0010
# Epoch 53/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9703 - loss: 0.0846 - val_accuracy: 0.7842 - val_loss: 0.9174 - learning_rate: 0.0010
# Epoch 54/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9568 - loss: 0.1252 - val_accuracy: 0.7891 - val_loss: 0.8527 - learning_rate: 0.0010
# Epoch 55/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9704 - loss: 0.0845 - val_accuracy: 0.8044 - val_loss: 0.8051 - learning_rate: 0.0010
# Epoch 56/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9718 - loss: 0.0861
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9718 - loss: 0.0861 - val_accuracy: 0.7986 - val_loss: 0.8308 - learning_rate: 0.0010
# Epoch 57/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9716 - loss: 0.0853 - val_accuracy: 0.8204 - val_loss: 0.7758 - learning_rate: 5.0000e-04
# Epoch 58/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9860 - loss: 0.0432 - val_accuracy: 0.8249 - val_loss: 0.8063 - learning_rate: 5.0000e-04
# Epoch 59/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 247ms/step - accuracy: 0.9884 - loss: 0.0351 - val_accuracy: 0.8303 - val_loss: 0.7538 - learning_rate: 5.0000e-04
# Epoch 60/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9913 - loss: 0.0275 - val_accuracy: 0.8278 - val_loss: 0.7944 - learning_rate: 5.0000e-04
# Epoch 61/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9883 - loss: 0.0361 - val_accuracy: 0.8327 - val_loss: 0.7836 - learning_rate: 5.0000e-04
# Epoch 62/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9895 - loss: 0.0299 - val_accuracy: 0.8315 - val_loss: 0.8094 - learning_rate: 5.0000e-04
# Epoch 63/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9920 - loss: 0.0263 - val_accuracy: 0.8323 - val_loss: 0.8559 - learning_rate: 5.0000e-04
# Epoch 64/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9888 - loss: 0.0325 - val_accuracy: 0.8282 - val_loss: 0.8494 - learning_rate: 5.0000e-04
# Epoch 65/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9914 - loss: 0.0276 - val_accuracy: 0.8278 - val_loss: 0.8209 - learning_rate: 5.0000e-04
# Epoch 66/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9907 - loss: 0.0258 - val_accuracy: 0.8319 - val_loss: 0.8397 - learning_rate: 5.0000e-04
# Epoch 67/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9901 - loss: 0.0280 - val_accuracy: 0.8245 - val_loss: 0.8751 - learning_rate: 5.0000e-04
# Epoch 68/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9822 - loss: 0.0545
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 82s 247ms/step - accuracy: 0.9822 - loss: 0.0544 - val_accuracy: 0.8208 - val_loss: 0.8515 - learning_rate: 5.0000e-04
# Epoch 69/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9914 - loss: 0.0277 - val_accuracy: 0.8323 - val_loss: 0.8191 - learning_rate: 2.5000e-04
# Epoch 70/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9932 - loss: 0.0202 - val_accuracy: 0.8298 - val_loss: 0.8273 - learning_rate: 2.5000e-04
# Epoch 71/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9949 - loss: 0.0161 - val_accuracy: 0.8393 - val_loss: 0.8153 - learning_rate: 2.5000e-04
# Epoch 72/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9957 - loss: 0.0122 - val_accuracy: 0.8331 - val_loss: 0.8521 - learning_rate: 2.5000e-04
# Epoch 73/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9941 - loss: 0.0175 - val_accuracy: 0.8315 - val_loss: 0.8299 - learning_rate: 2.5000e-04
# Epoch 74/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9956 - loss: 0.0131 - val_accuracy: 0.8327 - val_loss: 0.8515 - learning_rate: 2.5000e-04
# Epoch 75/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9963 - loss: 0.0123 - val_accuracy: 0.8356 - val_loss: 0.8507 - learning_rate: 2.5000e-04
# Epoch 76/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9958 - loss: 0.0133 - val_accuracy: 0.8418 - val_loss: 0.8356 - learning_rate: 2.5000e-04
# Epoch 77/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9947 - loss: 0.0185 - val_accuracy: 0.8356 - val_loss: 0.8728 - learning_rate: 2.5000e-04
# Epoch 78/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 82s 246ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.8348 - val_loss: 0.8773 - learning_rate: 2.5000e-04
# Epoch 79/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9948 - loss: 0.0149 - val_accuracy: 0.8364 - val_loss: 0.8844 - learning_rate: 2.5000e-04
# Epoch 80/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9956 - loss: 0.0125 - val_accuracy: 0.8319 - val_loss: 0.8988 - learning_rate: 2.5000e-04
# Epoch 81/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9956 - loss: 0.0138 - val_accuracy: 0.8397 - val_loss: 0.8314 - learning_rate: 2.5000e-04
# Epoch 82/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9957 - loss: 0.0120 - val_accuracy: 0.8409 - val_loss: 0.8910 - learning_rate: 2.5000e-04
# Epoch 83/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 247ms/step - accuracy: 0.9956 - loss: 0.0118 - val_accuracy: 0.8459 - val_loss: 0.8599 - learning_rate: 2.5000e-04
# Epoch 84/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9975 - loss: 0.0088 - val_accuracy: 0.8438 - val_loss: 0.8704 - learning_rate: 2.5000e-04
# Epoch 85/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9966 - loss: 0.0105 - val_accuracy: 0.8418 - val_loss: 0.8815 - learning_rate: 2.5000e-04
# Epoch 86/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9968 - loss: 0.0090 - val_accuracy: 0.8397 - val_loss: 0.8816 - learning_rate: 2.5000e-04
# Epoch 87/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9967 - loss: 0.0089 - val_accuracy: 0.8413 - val_loss: 0.9091 - learning_rate: 2.5000e-04
# Epoch 88/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 82s 247ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.8397 - val_loss: 0.8919 - learning_rate: 2.5000e-04
# Epoch 89/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9964 - loss: 0.0104 - val_accuracy: 0.8372 - val_loss: 0.9120 - learning_rate: 2.5000e-04
# Epoch 90/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9980 - loss: 0.0064
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.8401 - val_loss: 0.9344 - learning_rate: 2.5000e-04
# Epoch 91/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9969 - loss: 0.0088 - val_accuracy: 0.8459 - val_loss: 0.8973 - learning_rate: 1.2500e-04
# Epoch 92/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 245ms/step - accuracy: 0.9969 - loss: 0.0080 - val_accuracy: 0.8356 - val_loss: 0.9441 - learning_rate: 1.2500e-04
# Epoch 93/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9971 - loss: 0.0085 - val_accuracy: 0.8405 - val_loss: 0.9066 - learning_rate: 1.2500e-04
# Epoch 94/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9971 - loss: 0.0093 - val_accuracy: 0.8467 - val_loss: 0.8825 - learning_rate: 1.2500e-04
# Epoch 95/95
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 75s 246ms/step - accuracy: 0.9976 - loss: 0.0072 - val_accuracy: 0.8376 - val_loss: 0.9106 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 94.

# %% [markdown]
# # Testing the Model

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Test Accuracy: 84.67%

# %%
import numpy as np

# Assuming a binary classification model; adjust accordingly for multi-class
predictions = model.predict(X_test_scaled)
y_pred = np.argmax(predictions, axis=1)
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step

# %%
label_mapping = {
    "angry": 0,
    "calm": 1,
    "disgust": 2,
    "fear": 3,
    "happy": 4,
    "neutral": 5,
    "sad": 6,
    "surprised": 7
}

sorted_labels = sorted(label_mapping, key=label_mapping.get)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Assuming y_pred is already calculated and y_test is properly formatted
y_testing = np.argmax(y_test, axis=1)

# Generate classification report using the sorted_labels for target_names
print(classification_report(y_testing, y_pred, target_names=sorted_labels))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.91      0.87      0.89       387
#         calm       0.61      0.85      0.71        41
#      disgust       0.84      0.84      0.84       419
#         fear       0.83      0.83      0.83       377
#        happy       0.85      0.83      0.84       380
#      neutral       0.85      0.88      0.86       307
#          sad       0.81      0.83      0.82       413
#    surprised       0.94      0.90      0.92       109
#
#     accuracy                           0.85      2433
#    macro avg       0.83      0.85      0.84      2433
# weighted avg       0.85      0.85      0.85      2433

# %%
import plotly.figure_factory as ff

# Define the axis labels based on the number of classes
class_labels = ['angry', 'calm', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprised']

cm = confusion_matrix(y_testing, y_pred, labels=range(len(class_labels)))
# Create a confusion matrix heatmap, note the reversal of cm and y-axis labels
fig = ff.create_annotated_heatmap(z=cm, x=class_labels, y=class_labels, colorscale='Viridis')

# Add labels and title
fig.update_layout(title_text='<b>Confusion Matrix for Multi-Class Classification</b>',
                  xaxis=dict(title='Predicted label'),
                  yaxis=dict(title='True label', autorange="reversed"))  # Ensure y-axis starts from the top

# Add color scale
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="1a68ccdf-80ee-471a-ad1a-27f292564cf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a68ccdf-80ee-471a-ad1a-27f292564cf1")) {                    Plotly.newPlot(                        "1a68ccdf-80ee-471a-ad1a-27f292564cf1",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"x":["angry","calm","disgust","fear","happy","neutral","sad","surprised"],"y":["angry","calm","disgust","fear","happy","neutral","sad","surprised"],"z":[[336,0,21,9,15,4,1,1],[0,35,1,0,0,3,2,0],[10,3,351,6,12,15,21,1],[7,3,6,314,20,3,24,0],[17,1,13,12,314,10,12,1],[0,5,8,5,3,269,17,0],[0,9,15,27,5,11,343,3],[0,1,2,4,2,0,2,98]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"336","x":"angry","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"calm","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"21","x":"disgust","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"9","x":"fear","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"15","x":"happy","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"4","x":"neutral","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1","x":"sad","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1","x":"surprised","xref":"x","y":"angry","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"angry","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"35","x":"calm","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1","x":"disgust","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"fear","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"happy","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"3","x":"neutral","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"2","x":"sad","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"surprised","xref":"x","y":"calm","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"10","x":"angry","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"3","x":"calm","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"351","x":"disgust","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"6","x":"fear","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"12","x":"happy","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"15","x":"neutral","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"21","x":"sad","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1","x":"surprised","xref":"x","y":"disgust","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"7","x":"angry","xref":"x","y":"fear","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"3","x":"calm","xref":"x","y":"fear","yref":"y"},{"font":{"color ...

# %%
# model.save('Research-Main-Audio-Model.h5')
